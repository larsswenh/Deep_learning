# %% [markdown]
# # Lab 10.02 : Pooling layer - demo

# %%
import torch
import torch.nn as nn

# %% [markdown]
# ### Make a pooling module
# * inputs:  activation maps of size n x n
# * output:  activation maps of size n/p x n/p
# * p: pooling size

# %%
mod = nn.MaxPool2d(2,2)

# %% [markdown]
# ### Make an input 2 x 6 x 6  (two channels, each one has 6 x 6 pixels )

# %%
bs=1

x=torch.rand(bs,2,6,6)


print(x)
print(x.size())
# Out:
# tensor([[[[0.1488, 0.8045, 0.6751, 0.6204, 0.2787, 0.3643],
#           [0.1708, 0.6984, 0.1745, 0.9289, 0.5597, 0.4844],
#           [0.2398, 0.0499, 1.0000, 0.3815, 0.6905, 0.8999],
#           [0.1659, 0.0053, 0.4743, 0.0395, 0.0195, 0.0742],
#           [0.8688, 0.1963, 0.0561, 0.1154, 0.9142, 0.2739],
#           [0.3561, 0.4832, 0.5398, 0.2163, 0.8454, 0.1603]],
#
#          [[0.0050, 0.9268, 0.3398, 0.1703, 0.0057, 0.5810],
#           [0.6258, 0.4109, 0.8331, 0.3114, 0.6061, 0.3693],
#           [0.8580, 0.7635, 0.0750, 0.0010, 0.3089, 0.2158],
#           [0.6662, 0.2928, 0.6973, 0.4020, 0.6451, 0.8238],
#           [0.7745, 0.3076, 0.2890, 0.5898, 0.4049, 0.4983],
#           [0.2205, 0.6171, 0.7557, 0.6352, 0.9448, 0.7858]]]])
# torch.Size([1, 2, 6, 6])

# %% [markdown]
# ### Feed it to the pooling layer: the output size should be divided by 2

# %%
y=mod(x)

print(y)
print(y.size())
# Out:
# tensor([[[[0.8045, 0.9289, 0.5597],
#           [0.2398, 1.0000, 0.8999],
#           [0.8688, 0.5398, 0.9142]],
#
#          [[0.9268, 0.8331, 0.6061],
#           [0.8580, 0.6973, 0.8238],
#           [0.7745, 0.7557, 0.9448]]]])
# torch.Size([1, 2, 3, 3])
