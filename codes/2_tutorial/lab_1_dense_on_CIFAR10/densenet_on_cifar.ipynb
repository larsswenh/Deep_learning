# %% [markdown]
# # Dense networks on CIFAR10
#
# In this lab you will see how well neural networks with fully connected layers perform on a dataset with more complex images. For example, CIFAR10 images have RGB values and thus each pixel corresponds to three values.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data

import time

# %%
# Choose which device to use
use_cuda = True

if use_cuda and torch.cuda.is_available():
  device = torch.device('cuda')
else:
  device = torch.device('cpu')

device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Load the dataset

# %%
import torchvision
import torchvision.transforms as transforms

# Apply transformations to the data points before passing them to the network
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))])  # The data is normalized by subtracting the mean and dividing by the std (corresponding to each channel)

trainset = torchvision.datasets.CIFAR10(root='./data_cifar', train=True,
                                        download=True, transform=transform)

testset = torchvision.datasets.CIFAR10(root='./data_cifar', train=False,
                                       download=True, transform=transform)

batch_size = 128
w, h, c = 32, 32, 3  # Width, Height, Nr. of channels for the input images (RGB)
k = 10  # Number of output classes

trainloader = torch.utils.data.DataLoader(trainset,
                                          batch_size=batch_size,
                                          shuffle=True)

testloader = torch.utils.data.DataLoader(testset,
                                         batch_size=batch_size,
                                         shuffle=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# ### Show image examples

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

print(images[0].shape)
print(images.shape)

# show images
imshow(images[0])
imshow(torchvision.utils.make_grid(images))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.24864656..1.5654321].
# torch.Size([3, 32, 32])
# torch.Size([128, 3, 32, 32])
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.49473685..1.5654321].

# %% [markdown]
# ### Exercise - Defining an architecture
#
# In this lab we will use fully connected neural networks. Create a dense neural network class that has a variable number of layers and layer sizes. The hidden layers have ReLu activation. The output layer should not apply any activation function.

# %%
class MLP(nn.Module):

  def __init__(self,
               input_size,  # Size of the input. Here we will first flatten the image to a single vector with the 3 * 32 * 32 values in the image
               layer_sizes,  # A tuple containing the sizes of the hidden layers of the neural network. So to create a NN with two hidden layers with 32 neurons in each layer you'd set layer_sizes=(32,32)
               output_size):  # The size of the network output. CIFAR10 has 10 output classes
    super(MLP, self).__init__()
    shape = (input_size,) + tuple(layer_sizes) + (output_size,)
    self.linear = nn.ModuleList([nn.Linear(shape[i], shape[i+1]) for i in range(len(shape)-1)])

  def forward(self, x):
    for linear_layer in self.linear[:-1]:
      x = F.relu(linear_layer(x))
    return self.linear[-1](x)

# %%
model = MLP(w * h * c, (128, 128), k).to(device)  # Create a new dense neural network with two hidden layers of size 128

print(model)
# Out:
# MLP(
#   (linear): ModuleList(
#     (0): Linear(in_features=3072, out_features=128, bias=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ### Train the network
#
# Finish the code below so the network is trained on the images. The network should be able to reach an accuracy of about 50%. This is much better than taking random guesses, so the network did learn something. However, it is not a great classifier either. Dense neural networks are usually not the way to go for image classification. Instead, Convolutional Neural Networks are often used. These will be covered in the next lecture.

# %%
start=time.time()

criterion = nn.CrossEntropyLoss()

lr = 0.01 # COMPLETE THE CODE HERE
momentum = 0.5 # COMPLETE THE CODE HERE
num_epochs = 5 # COMPLETE THE CODE HERE

optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum)

for epoch in range(1, num_epochs + 1):
  # Iterate through the entire train set
  for i, (x_batch, y_batch) in enumerate(trainloader):
    x_batch, y_batch = x_batch.to(device), y_batch.to(device)  # Move the data to the device that is used

    # Perform an optimization step on the network weights using the gradient of the loss function
    optimizer.zero_grad()

    flatten = x_batch.view(-1, w*c*h)

    # COMPLETE THE CODE HERE

    y_pred = model(flatten) # COMPLETE THE CODE HERE

    loss = criterion(y_pred, y_batch) # COMPLETE THE CODE HERE
    loss.backward()
    # COMPLETE THE CODE HERE
    optimizer.step()

    # Compute relevant metrics

    y_pred_max = torch.argmax(y_pred, dim=1)  # Get the labels with highest output probability

    correct = torch.sum(torch.eq(y_pred_max, y_batch)).item()  # Count how many are equal to the true labels

    elapsed = time.time() - start  # Keep track of how much time has elapsed

    # Show progress every 20 batches
    if not i % 20:
      print(f'epoch: {epoch}, time: {elapsed:.3f}s, loss: {loss.item():.3f}, train accuracy: {correct / batch_size:.3f}')

  # Evaluate the model on the test set
  correct_total = 0
  for i, (x_batch, y_batch) in enumerate(testloader):
    x_batch, y_batch = x_batch.to(device), y_batch.to(device)  # Move the data to the device that is used

    y_pred = model(x_batch.view(-1, w * h * c))
    y_pred_max = torch.argmax(y_pred, dim=1)

    correct_total += torch.sum(torch.eq(y_pred_max, y_batch)).item()

  print(f'Test accuracy: {correct_total / len(testset.data):.3f}')
# Out:
# epoch: 1, time: 0.034s, loss: 2.295, train accuracy: 0.125
# epoch: 1, time: 0.562s, loss: 2.225, train accuracy: 0.203
# epoch: 1, time: 1.113s, loss: 2.169, train accuracy: 0.266
# epoch: 1, time: 1.646s, loss: 2.155, train accuracy: 0.172
# epoch: 1, time: 2.194s, loss: 2.143, train accuracy: 0.250
# epoch: 1, time: 2.736s, loss: 2.086, train accuracy: 0.188
# epoch: 1, time: 3.275s, loss: 2.013, train accuracy: 0.281
# epoch: 1, time: 3.792s, loss: 1.886, train accuracy: 0.375
# epoch: 1, time: 4.325s, loss: 1.972, train accuracy: 0.328
# epoch: 1, time: 4.945s, loss: 1.882, train accuracy: 0.289
# epoch: 1, time: 5.679s, loss: 1.824, train accuracy: 0.398
# epoch: 1, time: 6.446s, loss: 1.717, train accuracy: 0.391
# epoch: 1, time: 7.191s, loss: 1.817, train accuracy: 0.344
# epoch: 1, time: 7.723s, loss: 1.939, train accuracy: 0.359
# epoch: 1, time: 8.280s, loss: 1.960, train accuracy: 0.305
# epoch: 1, time: 8.808s, loss: 1.716, train accuracy: 0.344
# epoch: 1, time: 9.352s, loss: 1.671, train accuracy: 0.422
# epoch: 1, time: 9.872s, loss: 1.755, train accuracy: 0.359
# epoch: 1, time: 10.420s, loss: 1.816, train accuracy: 0.422
# epoch: 1, time: 10.958s, loss: 1.645, train accuracy: 0.438
# Test accuracy: 0.395
# epoch: 2, time: 13.259s, loss: 1.572, train accuracy: 0.422
# epoch: 2, time: 13.786s, loss: 1.582, train accuracy: 0.484
# epoch: 2, time: 14.344s, loss: 1.584, train accuracy: 0.453
# epoch: 2, time: 14.932s, loss: 1.693, train accuracy: 0.383
# epoch: 2, time: 15.476s, loss: 1.636, train accuracy: 0.430
# epoch: 2, time: 16.005s, loss: 1.661, train accuracy: 0.422
# epoch: 2, time: 16.541s, loss: 1.681, train accuracy: 0.438
# epoch: 2, time: 17.205s, loss: 1.711, train accuracy: 0.352
# epoch: 2, time: 17.957s, loss: 1.639, train accuracy: 0.398
# epoch: 2, time: 18.762s, loss: 1.678, train accuracy: 0.398
# epoch: 2, time: 19.324s, loss: 1.515, train accuracy: 0.477
# epoch: 2, time: 19.857s, loss: 1.684, train accuracy: 0.445
# epoch: 2, time: 20.381s, loss: 1.651, train accuracy: 0.391
# epoch: 2, time: 20.915s, loss: 1.627, train accuracy: 0.477
# epoch: 2, time: 21.436s, loss: 1.564, train accuracy: 0.445
# epoch: 2, time: 21.987s, loss: 1.569, train accuracy: 0.469
# epoch: 2, time: 22.521s, loss: 1.530, train accuracy: 0.461
# epoch: 2, time: 23.065s, loss: 1.567, train accuracy: 0.500
# epoch: 2, time: 23.595s, loss: 1.476, train accuracy: 0.508
# epoch: 2, time: 24.142s, loss: 1.751, train accuracy: 0.375
# Test accuracy: 0.445
# epoch: 3, time: 26.401s, loss: 1.456, train accuracy: 0.516
# epoch: 3, time: 26.938s, loss: 1.486, train accuracy: 0.461
# epoch: 3, time: 27.469s, loss: 1.524, train accuracy: 0.484
# epoch: 3, time: 28.001s, loss: 1.587, train accuracy: 0.375
# epoch: 3, time: 28.528s, loss: 1.550, train accuracy: 0.445
# epoch: 3, time: 29.198s, loss: 1.589, train accuracy: 0.469
# epoch: 3, time: 29.935s, loss: 1.420, train accuracy: 0.461
# epoch: 3, time: 30.726s, loss: 1.398, train accuracy: 0.484
# epoch: 3, time: 31.316s, loss: 1.524, train accuracy: 0.414
# epoch: 3, time: 31.851s, loss: 1.551, train accuracy: 0.422
# epoch: 3, time: 32.393s, loss: 1.484, train accuracy: 0.500
# epoch: 3, time: 32.914s, loss: 1.531, train accuracy: 0.438
# epoch: 3, time: 33.463s, loss: 1.602, train accuracy: 0.398
# epoch: 3, time: 33.998s, loss: 1.546, train accuracy: 0.477
# epoch: 3, time: 34.522s, loss: 1.552, train accuracy: 0.430
# epoch: 3, time: 35.090s, loss: 1.529, train accuracy: 0.430
# epoch: 3, time: 35.618s, loss: 1.606, train accuracy: 0.438
# epoch: 3, time: 36.159s, loss: 1.528, train accuracy: 0.500
# epoch: 3, time: 36.701s, loss: 1.486, train accuracy: 0.508
# epoch: 3, time: 37.254s, loss: 1.511, train accuracy: 0.445
# Test accuracy: 0.468
# epoch: 4, time: 39.524s, loss: 1.594, train accuracy: 0.391
# epoch: 4, time: 40.045s, loss: 1.519, train accuracy: 0.500
# epoch: 4, time: 40.584s, loss: 1.474, train accuracy: 0.492
# epoch: 4, time: 41.256s, loss: 1.479, train accuracy: 0.492
# epoch: 4, time: 41.976s, loss: 1.351, train accuracy: 0.531
# epoch: 4, time: 42.857s, loss: 1.465, train accuracy: 0.531
# epoch: 4, time: 43.436s, loss: 1.443, train accuracy: 0.484
# epoch: 4, time: 43.944s, loss: 1.395, train accuracy: 0.531
# epoch: 4, time: 44.477s, loss: 1.575, train accuracy: 0.469
# epoch: 4, time: 45.029s, loss: 1.487, train accuracy: 0.445
# epoch: 4, time: 45.617s, loss: 1.367, train accuracy: 0.516
# epoch: 4, time: 46.144s, loss: 1.521, train accuracy: 0.469
# epoch: 4, time: 46.694s, loss: 1.481, train accuracy: 0.438
# epoch: 4, time: 47.217s, loss: 1.348, train accuracy: 0.523
# epoch: 4, time: 47.819s, loss: 1.408, train accuracy: 0.492
# epoch: 4, time: 48.360s, loss: 1.566, train accuracy: 0.469
# epoch: 4, time: 48.900s, loss: 1.387, train accuracy: 0.547
# epoch: 4, time: 49.447s, loss: 1.381, train accuracy: 0.500
# epoch: 4, time: 49.999s, loss: 1.614, train accuracy: 0.430
# epoch: 4, time: 50.534s, loss: 1.449, train accuracy: 0.508
# Test accuracy: 0.484
# epoch: 5, time: 52.862s, loss: 1.359, train accuracy: 0.492
# epoch: 5, time: 53.611s, loss: 1.310, train accuracy: 0.594
# epoch: 5, time: 54.381s, loss: 1.319, train accuracy: 0.578
# epoch: 5, time: 55.148s, loss: 1.277, train accuracy: 0.500
# epoch: 5, time: 55.687s, loss: 1.469, train accuracy: 0.477
# epoch: 5, time: 56.239s, loss: 1.590, train accuracy: 0.500
# epoch: 5, time: 56.768s, loss: 1.309, train accuracy: 0.516
# epoch: 5, time: 57.300s, loss: 1.256, train accuracy: 0.547
# epoch: 5, time: 57.815s, loss: 1.335, train accuracy: 0.523
# epoch: 5, time: 58.349s, loss: 1.338, train accuracy: 0.562
# epoch: 5, time: 58.857s, loss: 1.374, train accuracy: 0.469
# epoch: 5, time: 59.408s, loss: 1.415, train accuracy: 0.555
# epoch: 5, time: 59.956s, loss: 1.475, train accuracy: 0.477
# epoch: 5, time: 60.492s, loss: 1.371, train accuracy: 0.539
# epoch: 5, time: 61.035s, loss: 1.470, train accuracy: 0.469
# epoch: 5, time: 61.569s, loss: 1.462, train accuracy: 0.500
# epoch: 5, time: 62.109s, loss: 1.440, train accuracy: 0.516
# epoch: 5, time: 62.629s, loss: 1.471, train accuracy: 0.461
# epoch: 5, time: 63.158s, loss: 1.526, train accuracy: 0.438
# epoch: 5, time: 63.693s, loss: 1.312, train accuracy: 0.508
# Test accuracy: 0.488
